# %%
;# Import all libraries needed for the tutorial
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Enable inline plotting
# %matplotlib inline

# %%
df = pd.read_csv('inspections.csv')
df.head(10)
# Out:
#   activity_date employee_id          facility_address     facility_city  \
# 0    2017-05-09   EE0000593       17660 CHATSWORTH ST     GRANADA HILLS
# 1    2017-04-10   EE0000126    3615 PACIFIC COAST HWY          TORRANCE
# 2    2017-04-04   EE0000593       17515 CHATSWORTH ST     GRANADA HILLS
# 3    2017-08-15   EE0000971  44455 VALLEY CENTRAL WAY         LANCASTER
# 4    2016-09-26   EE0000145            11700 SOUTH ST           ARTESIA
# 5    2016-05-11   EE0000720          1309 S HOOVER ST       LOS ANGELES
# 6    2017-02-28   EE0000741            4959 PATATA ST            CUDAHY
# 7    2016-11-03   EE0000721             524 S MAIN ST       LOS ANGELES
# 8    2016-02-17   EE0000742          333 W BONITA AVE         CLAREMONT
# 9    2017-04-18   EE0000745         11954 E CARSON ST  HAWAIIAN GARDENS
#
#   facility_id               facility_name facility_state facility_zip grade  \
# 0   FA0175397  HOVIK'S FAMOUS MEAT & DELI             CA        91344     A
# ...

# %%
df.grade.value_counts()
# Out:
# A    181278
# B      9379
# C       682
#          32
# Name: grade, dtype: int64

# %%
df.columns
# Out:
# Index(['activity_date', 'employee_id', 'facility_address', 'facility_city',
#        'facility_id', 'facility_name', 'facility_state', 'facility_zip',
#        'grade', 'owner_id', 'owner_name', 'pe_description',
#        'program_element_pe', 'program_name', 'program_status', 'record_id',
#        'score', 'serial_number', 'service_code', 'service_description'],
#       dtype='object')

# %%
df['activity_date'].max()
# Out:
# '2017-12-29'

# %%
df['activity_date'].min()
# Out:
# '2015-07-01'

# %%
df.groupby('facility_zip').nunique()
# Out:
#               activity_date  employee_id  facility_address  facility_city  \
# facility_zip
# 90001                   318            7               222              2
# 90001-1002                4            1                 1              1
# 90001-1127                9            1                 2              1
# 90001-1222                1            1                 1              1
# 90001-1312                1            1                 1              1
# 90001-1644                1            1                 1              1
# 90001-1646                4            1                 1              1
# 90001-1710                1            1                 1              1
# 90001-1771                7            1                 3              1
# 90001-1830                2            1                 1              1
# 90001-1966                5            1                 1              1
# ...

# %%
df['short_zip'] = df['facility_zip'].str[0:5]
#df['short_zip'] = df['facility_zip'][0:5]
df[['facility_zip', 'short_zip']]
# Out:
#        facility_zip short_zip
# 0             91344     91344
# 1             90505     90505
# 2             91344     91344
# 3             93536     93536
# 4             90701     90701
# 5        90006-4903     90006
# 6             90201     90201
# 7             90013     90013
# 8             91711     91711
# 9             90716     90716
# 10            90015     90015
# 11            90640     90640
# 12            90745     90745
# 13            91602     91602
# 14            90079     90079
# 15            90255     90255
# 16            91303     91303
# 17            91324     91324
# 18            91723     91723
# 19            91744     91744
# 20            93551     93551
# 21            90046     90046
# 22            90703     90703
# 23            90025     90025
# 24            91201     91201
# 25            90638     90638
# 26       90701-3804     90701
# 27            90277     90277
# 28            90704     90704
# 29            91608     91608
# ...

# %% [markdown]
# ### look at different percentiles (inspection date nunique) to find which zip codes have large/small number of entries

# %%
df.groupby('short_zip').nunique().head()
# Out:
#            activity_date  employee_id  facility_address  facility_city  \
# short_zip
# 90001                334            9               239              2
# 90002                140            6                58              1
# 90003                341            9               247              1
# 90004                404           11               234              1
# 90005                422           10               258              1
#
#            facility_id  facility_name  facility_state  facility_zip  grade  \
# short_zip
# 90001              264            254               1            23      3
# 90002               68             65               1             9      3
# 90003              268            258               1            35      3
# 90004              271            264               1            22      3
# 90005              296            286               1            22      4
#
# ...

# %% [markdown]
# ###

# %%
df.groupby('short_zip').count()['activity_date'].max()
# Out:
# 2215

# %%
df.shape
# Out:
# (191371, 21)

# %%
df.score.min()
# Out:
# 54

# %%
# df.loc(df.score == 54)
df[df.score == 54]
# Out:
#        activity_date employee_id      facility_address facility_city  \
# 134037    2017-07-11   EE0000829  888 E DOMINGUEZ ST E        CARSON
#
#        facility_id  facility_name facility_state facility_zip grade  \
# 134037   FA0007895  CARSON BUFFET             CA        90746
#
#          owner_id    ...                          pe_description  \
# 134037  OW0006281    ...     RESTAURANT (151 + ) SEATS HIGH RISK
#
#        program_element_pe   program_name program_status  record_id score  \
# 134037               1641  CARSON BUFFET       INACTIVE  PR0021633    54
#
#         serial_number service_code  service_description short_zip
# 134037      DAREI9PD0            1   ROUTINE INSPECTION     90746
#
# [1 rows x 21 columns]

# %%
df.groupby('program_status').count()
# Out:
#                 activity_date  employee_id  facility_address  facility_city  \
# program_status
# ACTIVE                 169477       169477            169477         169477
# INACTIVE                21894        21894             21894          21894
#
#                 facility_id  facility_name  facility_state  facility_zip  \
# program_status
# ACTIVE               169477         169477          169477        169477
# INACTIVE              21894          21894           21894         21894
#
#                  grade  owner_id  owner_name  pe_description  \
# program_status
# ACTIVE          169477    169477      169477          169477
# INACTIVE         21894     21894       21894           21894
#
#                 program_element_pe  program_name  record_id   score  \
# program_status
# ACTIVE                      169477        169139     169477  169477
# INACTIVE                     21894         21830      21894   21894
#
# ...

# %%
actives = df[df['program_status'] == 'ACTIVE']

# %%
df.groupby('facility_name').count().head()
# Out:
#                       activity_date  employee_id  facility_address  \
# facility_name
# "R" KITCHEN                       6            6                 6
# #1 BUFFET                         8            8                 8
# #1 CAFE                           5            5                 5
# #1 CHINESE FAST FOOD              6            6                 6
# #1 DELICIOUS DONUTS               4            4                 4
#
#                       facility_city  facility_id  facility_state  \
# facility_name
# "R" KITCHEN                       6            6               6
# #1 BUFFET                         8            8               8
# #1 CAFE                           5            5               5
# #1 CHINESE FAST FOOD              6            6               6
# #1 DELICIOUS DONUTS               4            4               4
#
#                       facility_zip  grade  owner_id  owner_name  \
# facility_name
# ...

# %%
actives.groupby('program_name').count()
# Out:
#                                   activity_date  employee_id  \
# program_name
# "POP'S CHICKEN"  MEXICAN FOOD                 7            7
# "R" KITCHEN                                   6            6
# # 245 BASE BOWLS                              8            8
# # 431 LOGE TERRACE BAR                        5            5
# # 953 TOP DECK DOGS                           7            7
# #1 BUFFET                                     8            8
# #1 CAFE                                       5            5
# #1 CHINESE FAST FOOD                          6            6
# #1 DELICIOUS DONUTS                           4            4
# #1 DONUTS                                     3            3
# #1 NOODLE HOUSE                               2            2
# #1. JUICY DUMPLING                            6            6
# #102 ALL INCLUSIVE (AYCE)                     5            5
# #103 DODGER DOG TRADITIONAL                   5            5
# ...

# %%
df.groupby('service_description').count()
# Out:
#                                   activity_date  employee_id  \
# service_description
# OWNER INITIATED ROUTINE INSPECT.           2908         2908
# ROUTINE INSPECTION                       188463       188463
#
#                                   facility_address  facility_city  \
# service_description
# OWNER INITIATED ROUTINE INSPECT.              2908           2908
# ROUTINE INSPECTION                          188463         188463
#
#                                   facility_id  facility_name  facility_state  \
# service_description
# OWNER INITIATED ROUTINE INSPECT.         2908           2908            2908
# ROUTINE INSPECTION                     188463         188463          188463
#
#                                   facility_zip   grade  owner_id  owner_name  \
# service_description
# OWNER INITIATED ROUTINE INSPECT.          2908    2908      2908        2908
# ROUTINE INSPECTION                      188463  188463    188463      188463
#
# ...

# %%
df.describe()
# Out:
#        program_element_pe          score   service_code
# count       191371.000000  191371.000000  191371.000000
# mean          1629.888980      93.753306       7.078246
# std              9.391426       3.845518      48.932257
# min           1610.000000      54.000000       1.000000
# 25%           1631.000000      91.000000       1.000000
# 50%           1632.000000      94.000000       1.000000
# 75%           1635.000000      97.000000       1.000000
# max           1641.000000     100.000000     401.000000

# %%
# df['grade' == 'A']
df[df['grade'] == ' ']
# Out:
#        activity_date employee_id             facility_address  \
# 766       2017-09-20   EE0000163         14021 S PIONEER BLVD
# 891       2017-02-07   EE0000821     745 E GARVEY AVE STE 101
# 9002      2017-04-05   EE0000821           108 N GARFIELD AVE
# 11308     2016-09-21   EE0000854                3418 W 8TH ST
# 14439     2015-09-10   EE0000882        2210 MARINE AVE STE J
# 20672     2017-08-24   EE0000829              21705 S MAIN ST
# 25097     2017-12-13   EE0000182                12819 PENN ST
# 39392     2017-02-22   EE0000735       24947 W PICO CANYON RD
# 71731     2017-06-21   EE0000829              313 E CARSON ST
# 75325     2017-04-26   EE0000747             2423 S AZUSA AVE
# 95092     2017-08-28   EE0000145         19008 S PIONEER BLVD
# 99230     2017-06-20   EE0000821            245 W VALLEY BLVD
# 99679     2017-02-27   EE0000018  14426 S CRENSHAW BLVD STE D
# 107327    2015-10-06   EE0000742   18472 E COLIMA RD STE #100
# ...
